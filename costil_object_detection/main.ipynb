# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
from time import time

# %%
img = cv2.imread('horse.jpg')

# %%
plt.imshow(img)

# %%
net = cv2.dnn.readNetFromDarknet('yolov2-tiny.cfg', 'yolov2-tiny.weights')

# %%
net.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)

# %%
ln = net.getLayerNames()
print(len(ln), ln)
# Out:
# 33 ('conv_0', 'bn_0', 'leaky_1', 'pool_1', 'conv_2', 'bn_2', 'leaky_3', 'pool_3', 'conv_4', 'bn_4', 'leaky_5', 'pool_5', 'conv_6', 'bn_6', 'leaky_7', 'pool_7', 'conv_8', 'bn_8', 'leaky_9', 'pool_9', 'conv_10', 'bn_10', 'leaky_11', 'pool_11', 'conv_12', 'bn_12', 'leaky_13', 'conv_13', 'bn_13', 'leaky_14', 'conv_14', 'permute_15', 'detection_out')

# %%
blob = cv2.dnn.blobFromImage(img, 1/255.0, (416, 416), swapRB=True, crop=False)
r = blob[0, 0, :, :]

# %%
cv2.imshow('blob', r)

cv2.waitKey(1)
# Out:
# -1

# %%
net.setInput(blob)
t0 = time()
outputs = net.forward(ln)
t = time()

# %%
cv2.imshow('window',  img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
len(outputs)
# Out:
# 33
